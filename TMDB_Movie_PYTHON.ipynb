# %% [markdown]
# # TMDB Movie Data Analysis

# %% [markdown]
# # Business Objectives

# %% [markdown]
# #### 1.Analyse movie genres and their popularity, determine which genres are most produced and which are the most profitable.2.Analyse the relation of budget and revenue of movies to identify that whether it is a success or failure.3.Analyse the budget is really a matters of the popularity of a successful movie4.Analyse the top production company ,which produced number of films that comes in success or failure category.5.Analyse the runtime of the movie encourage the enthusiasm of movie lovers

# %% [markdown]
# ### Import the libraries

# %%
import matplotlib.pyplot as plt             # to visualize
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### TASK1

# %%
# Read the csv file
df= pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
#Displaying  the number of rows and columns in the dataset.
df.shape
# Out:
# (4803, 20)

# %%
# Displaying the title and genres of the first 50 movies from the dataset.
df[['title','genres']].head(51)
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# ### TASK2

# %%
# Identify the columns that have null values.
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# homepage
mode_value = df["homepage"].mode()[0]

# %%
mode_value
# Out:
# 'http://www.missionimpossible.com/'

# %%
# Fill missing categorical object data type values with the mode value
df["homepage"].fillna(value=mode_value, inplace=True)

# %%
# tagline
mode_value = df["tagline"].mode()[0]

# %%
mode_value
# Out:
# 'Based on a true story.'

# %%
# Fill missing categorical object data type values with the mode value
df["tagline"].fillna(value=mode_value, inplace=True)

# %%
# Overview
mode_value = df["overview"].mode()[0]

# %%
mode_value
# Out:
# ' '

# %%
# Fill missing categorical object data type values with the mode value
df["overview"].fillna(value=mode_value, inplace=True)

# %%
# release_data
mode_value = df["release_date"].mode()[0]

# Fill missing categorical object data type values with the mode value
df["release_date"].fillna(value=mode_value, inplace=True)

# %%
mode_value
# Out:
# '01-01-2006'

# %%
# runtime
mean_value = df["runtime"].mean()

# Fill missing Numerical object data type values with the mode value
df["runtime"].fillna(value=mean_value, inplace=True)

# %%
mean_value
# Out:
# 106.87585919600083

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# ### TASK3

# %%
#Display the movie categories that have a budget greater than $220,000
df_budget = df[df['budget'] > 220000]
df_budget
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4680     450000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4682   13000000                     [{"id": 27, "name": "Horror"}]
# 4720    8500000                      [{"id": 18, "name": "Drama"}]
# 4758    4000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 4770     500000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# ...

# %%
df_budget[['budget','revenue','genres']].tail(50)
# Out:
#         budget    revenue                                             genres
# 4542    500000    4242978  [{"id": 18, "name": "Drama"}, {"id": 53, "name...
# 4545    500000          0  [{"id": 35, "name": "Comedy"}, {"id": 27, "nam...
# 4548    500000          0                      [{"id": 18, "name": "Drama"}]
# 4552    500000          0  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4562    500000          0                                                 []
# 4567    450000     973525  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4570    439000    2281000  [{"id": 10402, "name": "Music"}, {"id": 35, "n...
# 4572    225000          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4575    400000   46118097                     [{"id": 35, "name": "Comedy"}]
# 4579    400000    5028948  [{"id": 12, "name": "Adventure"}, {"id": 35, "...
# 4586  35000000  170000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# ...

# %% [markdown]
# # TASK4

# %%
#Display the movies category where the revenue is greater than 961,000,000.
df_Revenue = df[(df['revenue'] > 961000000)]
df_Revenue
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 12   200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17   380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 32   200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 36   210000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...

# %% [markdown]
# ### TASK5

# %%
# Drop the rows which are having the 0 value present in the budget and revenue columns
df1 = df[(df['budget'] != 0) & (df['revenue'] != 0)]
df1
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### TASK6

# %%
#Top 10 movies with highest revenue
high_revenue=df1.sort_values('revenue',ascending=False)
high_revenue.head(10)
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 25                         http://www.titanicmovie.com     597
# ...

# %%
#Top 10 movies with the least budget
low_budget=df1.sort_values('budget',ascending=True)
low_budget.head(10)
# Out:
#       budget                                             genres  \
# 4238       1  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 3611       4  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3372       7  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 3419       7  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4608       8  [{"id": 14, "name": "Fantasy"}, {"id": 27, "na...
# 3131      10  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3137      10  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 2933      11  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 1912      25                      [{"id": 18, "name": "Drama"}]
# 1771      28  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
#
#                                homepage      id  \
# 4238  http://www.missionimpossible.com/    3082
# 3611  http://www.missionimpossible.com/   22649
# 3372  http://www.missionimpossible.com/   13006
# 3419  http://www.missionimpossible.com/   38415
# ...

# %% [markdown]
# ### TASK7

# %%
# Display the correlation as scatterplot

sns.scatterplot(x="popularity",
                    y="budget",
                    data=df1)
plt.title('Correlation between Popularity and budget')
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.heatmap(df1.corr(),annot= True ,cmap="Blues_r", cbar = True,linewidth=0.3)
plt.show()
print('Correlation value is : 0.431990 , it is a moderate positive correlation.')
# Out:
# Correlation value is : 0.431990 , it is a moderate positive correlation.

# %% [markdown]
# ### TASK8

# %%
#identyfy the unique vales
df1['production_companies'].unique().size
# Out:
# 2633

# %%
# display the name of companies and count and assign to variable a
a=df1['production_companies'].value_counts()

# %%
#create a dataframe with a(series)
companydf=pd.DataFrame(a)

# %%
#rename the column and index
companydf.rename(columns={'production_companies':'Count of Production Companies'},inplace=True)
companydf.index.name='production_companies'

# %%
companydf
# Out:
#                                                     Count of Production Companies
# production_companies
# [{"name": "Paramount Pictures", "id": 4}]                                      48
# []                                                                             41
# [{"name": "Universal Pictures", "id": 33}]                                     35
# [{"name": "New Line Cinema", "id": 12}]                                        29
# [{"name": "Columbia Pictures", "id": 5}]                                       28
# ...                                                                           ...
# [{"name": "Universal Pictures", "id": 33}, {"na...                              1
# [{"name": "Columbia Pictures", "id": 5}, {"name...                              1
# [{"name": "The Montecito Picture Company", "id"...                              1
# [{"name": "Camelot Productions", "id": 523}, {"...                              1
# ...

# %% [markdown]
# ### TASK9

# %%
# Select the top 25 production companies
production_df = companydf.sort_values('Count of Production Companies', ascending=False)
production_df.head(25)
# Out:
#                                                     Count of Production Companies
# production_companies
# [{"name": "Paramount Pictures", "id": 4}]                                      48
# []                                                                             41
# [{"name": "Universal Pictures", "id": 33}]                                     35
# [{"name": "New Line Cinema", "id": 12}]                                        29
# [{"name": "Columbia Pictures", "id": 5}]                                       28
# [{"name": "Twentieth Century Fox Film Corporati...                             25
# [{"name": "Warner Bros.", "id": 6194}]                                         24
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 84...                             24
# [{"name": "Walt Disney Pictures", "id": 2}]                                    18
# [{"name": "Touchstone Pictures", "id": 9195}]                                  15
# ...

# %% [markdown]
# ### TASK10

# %%
# Sort the data in descending order based on revenue and filter the top 500 movies
df1=df1.sort_values('revenue',ascending=False)

# %%
df2=df1.head(500)
df2
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 698    70000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 717    60000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 714    65000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# ...

# %%
# Calculate the measures of central tendency for budget, revenue, and runtime
def mean_median_mode():
    list=['budget','revenue','runtime']
    for i in list:
        print(f"The mean of the {i} is {df2[i].mean()}")
        print(f"The median of the {i} is {df2[i].median()}")
        print(f"The mode of the {i} is {df2[i].mode()[0]}")
        print('*'*40)
mean_median_mode()
# Out:
# The mean of the budget is 103193736.0
# The median of the budget is 95000000.0
# The mode of the budget is 150000000
# ****************************************
# The mean of the revenue is 458577595.062
# The median of the revenue is 363001569.5
# The mode of the revenue is 217764291
# ****************************************
# The mean of the runtime is 118.72
# The median of the runtime is 116.0
# The mode of the runtime is 115.0
# ****************************************

# %%
def outliers():
    list=['budget','revenue','runtime']
    for i in list:
        print(f"The mean of {i} is, {df2[i].mean()}")
        Q1=df2[i].quantile(0.25)
        Q3=df2[i].quantile(0.75)
        print('value of Q1 and Q3',Q1,',',Q3)
        IQR=Q3-Q1
        print('value of IQR',IQR)
        UF = Q3 + (1.5 * IQR) 
        LF = Q1 - (1.5 * IQR)
        print('value of UF and LF',UF,',',LF)
        print("-----------------------------------------------------")
outliers()
# Out:
# The mean of budget is, 103193736.0
# value of Q1 and Q3 55000000.0 , 150000000.0
# value of IQR 95000000.0
# value of UF and LF 292500000.0 , -87500000.0
# -----------------------------------------------------
# The mean of revenue is, 458577595.062
# value of Q1 and Q3 281447346.25 , 547133157.5
# value of IQR 265685811.25
# value of UF and LF 945661874.375 , -117081370.625
# -----------------------------------------------------
# The mean of runtime is, 118.72
# value of Q1 and Q3 100.0 , 132.0
# value of IQR 32.0
# value of UF and LF 180.0 , 52.0
# -----------------------------------------------------

# %%
# Perform outlier analysis using box plots
plt.figure(figsize=(8, 5))
plt.subplot(1, 3, 1)
plt.boxplot(df2['budget'], vert=False)
plt.title('Budget Box Plot')

plt.subplot(1, 3, 2)
plt.boxplot(df2['revenue'], vert=False)
plt.title('Revenue Box Plot')

plt.subplot(1, 3, 3)
plt.boxplot(df2['runtime'], vert=False)
plt.title('Runtime Box Plot')

plt.show()

# %%
# Calculate the average runtime
avg_runtime = df1['runtime'].mean()

# Filter movies with runtimes above the average
above_avg_runtime = df1[df1['runtime'] > avg_runtime]

# Create a DataFrame with movie names and runtimes
result_df = above_avg_runtime[['title','runtime']]

# Display the DataFrame
result_df
# Out:
#                 title  runtime
# 0              Avatar    162.0
# 25            Titanic    194.0
# 16       The Avengers    143.0
# 28     Jurassic World    124.0
# 44          Furious 7    137.0
# ...               ...      ...
# 4065       Mi America    126.0
# 2874       In the Cut    119.0
# 1912   Angela's Ashes    145.0
# 1655  Chasing Liberty    111.0
# 2933         F.I.S.T.    145.0
#
# [1362 rows x 2 columns]

# %%
avg_runtime
# Out:
# 110.72437287085785
